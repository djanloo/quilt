# %%
# !echo $PYTHONPATH
# %load_ext wurlitzer
# Out:
# /home/dianloo/Desktop/tesi/quilt

# %%
import numpy as np
import matplotlib.pyplot as plt
from quilt.builder import SpikingNetwork
import yaml
from rich import print

with open("spiking.yaml", "r") as network_file:
    # print(yaml.safe_load(network_file))        
    line = network_file.readline()
    while line:
        print(line.replace("\n", ""))     
        line = network_file.readline()
# Out:
# populations:
#   - name: Albert
#     size: 700
#     neuron_type: aeif
#   - name: MonaLisa
#     size: 700
#     neuron_type: aeif
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# projections:
#   - name: AtoM
#     efferent: Albert
#     afferent: MonaLisa
#     features:
#       inh_fraction: 0.2
#       max_inh: 0.1
#       min_delay: 10.7
#       max_delay: 15.0
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#   - name: albert-self
#     efferent: Albert
#     afferent: Albert
#     features:
#       inh_fraction: 0.05
#       max_inh: 0.1
#       min_delay: 0.1
#       exc_fraction: 0.0
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#   - name: MtoA
#     efferent: MonaLisa
#     afferent: Albert
#     features:
#       inh_fraction: 0.2
#       max_inh: 0.1
#       min_delay: 10.7
#       max_delay: 15.0
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#   - name: monalisa-self
#     efferent: MonaLisa
#     afferent: MonaLisa
#     features:
#       inh_fraction: 0.05
#       max_inh: 0.1
#       exc_fraction: 0.0

# %%
spikenet = SpikingNetwork.from_yaml("spiking.yaml")
# Out:
# Building population 0 took 0 ms    (0.775714 us/neur)
# Building population 1 took 0 ms    (0.335714 us/neur)
# generating weights and delays took 0.01765918731689453 seconds
# projection has density 20.138%
# performing 98666 connections took 4 ms   (0.045578 us/link)
# generating weights and delays took 0.014256477355957031 seconds
# projection has density 4.95408%
# performing 24270 connections took 1 ms   (0.0650597 us/link)
# generating weights and delays took 0.01681208610534668 seconds
# projection has density 19.9935%
# performing 97954 connections took 3 ms   (0.0382731 us/link)
# generating weights and delays took 0.01536107063293457 seconds
# projection has density 4.9898%
# performing 24447 connections took 1 ms   (0.0460179 us/link)

# %%
spikenet.populations["Albert"].monitorize_spikes()
spikenet.populations["Albert"].monitorize_states()

spikenet.populations["MonaLisa"].monitorize_spikes()
spikenet.populations["MonaLisa"].monitorize_states()

spikenet.interface.run(dt=0.1, time=200)
# Out:
# Adding spike monitor
# Adding state monitor
# Adding spike monitor
# Adding state monitor
# ------ Time: 0---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.752857 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.534286 us/neur )
# ------ Time: 0.1---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.814286 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.915714 us/neur )
# ------ Time: 0.2---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.538571 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.512857 us/neur )
# ------ Time: 0.3---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.522857 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.648571 us/neur )
# ------ Time: 0.4---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.61 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.601429 us/neur )
# ------ Time: 0.5---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.535714 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.502857 us/neur )
# ------ Time: 0.6---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.505714 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.504286 us/neur )
# ------ Time: 0.7---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.505714 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.514286 us/neur )
# ------ Time: 0.8---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.504286 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.508571 us/neur )
# ------ Time: 0.9---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.505714 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.507143 us/neur )
# ------ Time: 1---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.512857 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.505714 us/neur )
# ------ Time: 1.1---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.504286 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.505714 us/neur )
# ------ Time: 1.2---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.501429 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.504286 us/neur )
# ------ Time: 1.3---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.504286 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.504286 us/neur )
# ------ Time: 1.4---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.498571 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.508571 us/neur )
# ------ Time: 1.5---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.512857 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.51 us/neur )
# ------ Time: 1.6---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.858571 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.785714 us/neur )
# ------ Time: 1.7---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.51 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.535714 us/neur )
# ------ Time: 1.8---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.508571 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.507143 us/neur )
# ------ Time: 1.9---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.697143 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.52 us/neur )
# ------ Time: 2---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.52 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.78 us/neur )
# ------ Time: 2.1---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.51 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.504286 us/neur )
# ------ Time: 2.2---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.495714 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.497143 us/neur )
# ------ Time: 2.3---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.505714 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.7 us/neur )
# ------ Time: 2.4---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.562857 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.458571 us/neur )
# ------ Time: 2.5---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.46 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.455714 us/neur )
# ------ Time: 2.6---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.46 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.457143 us/neur )
# ------ Time: 2.7---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.455714 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.474286 us/neur )
# ------ Time: 2.8---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.462857 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.452857 us/neur )
# ------ Time: 2.9---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.477143 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.462857 us/neur )
# ------ Time: 3---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.458571 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.464286 us/neur )
# ------ Time: 3.1---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.458571 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.457143 us/neur )
# ------ Time: 3.2---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.464286 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.461429 us/neur )
# ------ Time: 3.3---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.457143 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.452857 us/neur )
# ------ Time: 3.4---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.47 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.481429 us/neur )
# ------ Time: 3.5---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.455714 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.455714 us/neur )
# ------ Time: 3.6---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.452857 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.53 us/neur )
# ------ Time: 3.7---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.915714 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.57 us/neur )
# ------ Time: 3.8---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.504286 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.507143 us/neur )
# ------ Time: 3.9---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.508571 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.502857 us/neur )
# ------ Time: 4---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.505714 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.474286 us/neur )
# ------ Time: 4.1---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.454286 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.46 us/neur )
# ------ Time: 4.2---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.454286 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.457143 us/neur )
# ------ Time: 4.3---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.458571 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.455714 us/neur )
# ------ Time: 4.4---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.49 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.46 us/neur )
# ------ Time: 4.5---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.667143 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.595714 us/neur )
# ------ Time: 4.6---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.508571 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.508571 us/neur )
# ------ Time: 4.7---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.462857 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.452857 us/neur )
# ------ Time: 4.8---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.458571 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.455714 us/neur )
# ------ Time: 4.9---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.498571 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.46 us/neur )
# ------ Time: 5---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.457143 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.457143 us/neur )
# ------ Time: 5.1---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.46 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.458571 us/neur )
# ------ Time: 5.2---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.458571 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.457143 us/neur )
# ------ Time: 5.3---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.461429 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.501429 us/neur )
# ------ Time: 5.4---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.518571 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.504286 us/neur )
# ------ Time: 5.5---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.507143 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.508571 us/neur )
# ------ Time: 5.6---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.537143 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.502857 us/neur )
# ------ Time: 5.7---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.454286 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.507143 us/neur )
# ------ Time: 5.8---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.505714 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.507143 us/neur )
# ------ Time: 5.9---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.514286 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.502857 us/neur )
# ------ Time: 6---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.471429 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.475714 us/neur )
# ------ Time: 6.1---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.458571 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.457143 us/neur )
# ------ Time: 6.2---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.461429 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.461429 us/neur )
# ------ Time: 6.3---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.458571 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.478571 us/neur )
# ------ Time: 6.4---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.492857 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.502857 us/neur )
# ------ Time: 6.5---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.511429 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.534286 us/neur )
# ------ Time: 6.6---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.652857 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.574286 us/neur )
# ------ Time: 6.7---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.522857 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.521429 us/neur )
# ------ Time: 6.8---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.515714 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.517143 us/neur )
# ------ Time: 6.9---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.457143 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.458571 us/neur )
# ------ Time: 7---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.467143 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.461429 us/neur )
# ------ Time: 7.1---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.458571 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.457143 us/neur )
# ------ Time: 7.2---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.457143 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.46 us/neur )
# ------ Time: 7.3---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.455714 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.452857 us/neur )
# ------ Time: 7.4---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.488571 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.452857 us/neur )
# ------ Time: 7.5---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.458571 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.461429 us/neur )
# ------ Time: 7.6---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.457143 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.461429 us/neur )
# ------ Time: 7.7---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.452857 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.47 us/neur )
# ------ Time: 7.8---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.455714 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.458571 us/neur )
# ------ Time: 7.9---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.505714 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.457143 us/neur )
# ------ Time: 8---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.462857 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.458571 us/neur )
# ------ Time: 8.1---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.46 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.458571 us/neur )
# ------ Time: 8.2---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.457143 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.461429 us/neur )
# ------ Time: 8.3---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.46 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.457143 us/neur )
# ------ Time: 8.4---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.455714 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.512857 us/neur )
# ------ Time: 8.5---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.504286 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.494286 us/neur )
# ------ Time: 8.6---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.46 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.462857 us/neur )
# ------ Time: 8.7---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.672857 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.555714 us/neur )
# ------ Time: 8.8---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.468571 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.457143 us/neur )
# ------ Time: 8.9---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.468571 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.474286 us/neur )
# ------ Time: 9---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.455714 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.455714 us/neur )
# ------ Time: 9.1---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.461429 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.458571 us/neur )
# ------ Time: 9.2---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.467143 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.462857 us/neur )
# ------ Time: 9.3---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.455714 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.46 us/neur )
# ------ Time: 9.4---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.454286 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.477143 us/neur )
# ------ Time: 9.5---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.462857 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.452857 us/neur )
# ------ Time: 9.6---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.457143 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.452857 us/neur )
# ------ Time: 9.7---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.455714 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.452857 us/neur )
# ------ Time: 9.8---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.454286 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.474286 us/neur )
# ------ Time: 9.9---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.5 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.502857 us/neur )
# ------ Time: 10---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.461429 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.46 us/neur )
# ------ Time: 10.1---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.452857 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.462857 us/neur )
# ------ Time: 10.2---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.455714 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.462857 us/neur )
# ------ Time: 10.3---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.455714 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.458571 us/neur )
# ------ Time: 10.4---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.461429 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.46 us/neur )
# ------ Time: 10.5---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.485714 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.478571 us/neur )
# ------ Time: 10.6---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.455714 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.457143 us/neur )
# ------ Time: 10.7---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.458571 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.511429 us/neur )
# ------ Time: 10.8---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.6 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.461429 us/neur )
# ------ Time: 10.9---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.461429 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.457143 us/neur )
# ------ Time: 11---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.485714 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.514286 us/neur )
# ------ Time: 11.1---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.511429 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.505714 us/neur )
# ------ Time: 11.2---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.457143 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.454286 us/neur )
# ------ Time: 11.3---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.46 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.461429 us/neur )
# ------ Time: 11.4---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.464286 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.454286 us/neur )
# ------ Time: 11.5---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.484286 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.482857 us/neur )
# ------ Time: 11.6---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.455714 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.46 us/neur )
# ------ Time: 11.7---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.455714 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.461429 us/neur )
# ------ Time: 11.8---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.457143 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.457143 us/neur )
# ------ Time: 11.9---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.457143 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.46 us/neur )
# ------ Time: 12---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.455714 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.505714 us/neur )
# ------ Time: 12.1---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.455714 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.455714 us/neur )
# ------ Time: 12.2---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.465714 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.457143 us/neur )
# ------ Time: 12.3---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.454286 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.455714 us/neur )
# ------ Time: 12.4---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.46 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.454286 us/neur )
# ------ Time: 12.5---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.452857 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.49 us/neur )
# ------ Time: 12.6---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.471429 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.452857 us/neur )
# ------ Time: 12.7---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.454286 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.454286 us/neur )
# ------ Time: 12.8---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.455714 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.461429 us/neur )
# ------ Time: 12.9---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.452857 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.627143 us/neur )
# ------ Time: 13---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.595714 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.502857 us/neur )
# ------ Time: 13.1---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.507143 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.507143 us/neur )
# ------ Time: 13.2---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.454286 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.457143 us/neur )
# ------ Time: 13.3---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.454286 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.458571 us/neur )
# ------ Time: 13.4---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.457143 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.452857 us/neur )
# ------ Time: 13.5---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.454286 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.46 us/neur )
# ------ Time: 13.6---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.482857 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.452857 us/neur )
# ------ Time: 13.7---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.458571 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.451429 us/neur )
# ------ Time: 13.8---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.457143 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.461429 us/neur )
# ------ Time: 13.9---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.467143 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.451429 us/neur )
# ------ Time: 14---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.455714 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.455714 us/neur )
# ------ Time: 14.1---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.458571 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.481429 us/neur )
# ------ Time: 14.2---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.454286 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.457143 us/neur )
# ------ Time: 14.3---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.454286 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.455714 us/neur )
# ------ Time: 14.4---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.46 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.454286 us/neur )
# ------ Time: 14.5---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.457143 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.454286 us/neur )
# ------ Time: 14.6---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.454286 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.465714 us/neur )
# ------ Time: 14.7---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.468571 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.46 us/neur )
# ------ Time: 14.8---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.457143 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.452857 us/neur )
# ------ Time: 14.9---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.462857 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.461429 us/neur )
# ------ Time: 15---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.454286 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.457143 us/neur )
# ------ Time: 15.1---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.55 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.578571 us/neur )
# ------ Time: 15.2---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.475714 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.457143 us/neur )
# ------ Time: 15.3---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.457143 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.457143 us/neur )
# ------ Time: 15.4---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.454286 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.452857 us/neur )
# ------ Time: 15.5---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.462857 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.46 us/neur )
# ------ Time: 15.6---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.458571 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.46 us/neur )
# ------ Time: 15.7---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.481429 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.46 us/neur )
# ------ Time: 15.8---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.455714 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.458571 us/neur )
# ------ Time: 15.9---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.458571 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.46 us/neur )
# ------ Time: 16---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.455714 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.452857 us/neur )
# ------ Time: 16.1---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.455714 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.455714 us/neur )
# ------ Time: 16.2---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 0 ms (0.455714 us/neur )
# pop 1) average synaptic queue is long 0
# pop 1) evolving took 0 ms (0.471429 us/neur )
# ------ Time: 16.3---------
# pop 0) average synaptic queue is long 0
# pop 0) evolving took 1 ms (2.38 us/neur )
# pop 1) average synaptic queue is long 34.2457
# pop 1) evolving took 1 ms (2.08714 us/neur )
# ------ Time: 16.4---------
# pop 0) average synaptic queue is long 45.2171
# pop 0) evolving took 1 ms (2.42857 us/neur )
# pop 1) average synaptic queue is long 77.9514
# pop 1) evolving took 1 ms (2.22857 us/neur )
# ------ Time: 16.5---------
# pop 0) average synaptic queue is long 85.6043
# pop 0) evolving took 1 ms (2.57571 us/neur )
# pop 1) average synaptic queue is long 119.179
# pop 1) evolving took 1 ms (2.76714 us/neur )
# ------ Time: 16.6---------
# pop 0) average synaptic queue is long 125.739
# pop 0) evolving took 2 ms (3.16 us/neur )
# pop 1) average synaptic queue is long 161.071
# pop 1) evolving took 1 ms (2.52143 us/neur )
# ------ Time: 16.7---------
# pop 0) average synaptic queue is long 161.911
# pop 0) evolving took 0 ms (1.07857 us/neur )
# pop 1) average synaptic queue is long 162.626
# pop 1) evolving took 0 ms (1.18714 us/neur )
# ------ Time: 16.8---------
# pop 0) average synaptic queue is long 153.399
# pop 0) evolving took 0 ms (0.984286 us/neur )
# pop 1) average synaptic queue is long 153.813
# pop 1) evolving took 0 ms (0.937143 us/neur )
# ------ Time: 16.9---------
# pop 0) average synaptic queue is long 146.676
# pop 0) evolving took 0 ms (0.82 us/neur )
# pop 1) average synaptic queue is long 147.303
# pop 1) evolving took 0 ms (0.791429 us/neur )
# ------ Time: 17---------
# pop 0) average synaptic queue is long 142.204
# pop 0) evolving took 0 ms (0.682857 us/neur )
# pop 1) average synaptic queue is long 142.99
# pop 1) evolving took 0 ms (0.71 us/neur )
# ------ Time: 17.1---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.485714 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.481429 us/neur )
# ------ Time: 17.2---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.474286 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.471429 us/neur )
# ------ Time: 17.3---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.475714 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.474286 us/neur )
# ------ Time: 17.4---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.474286 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.475714 us/neur )
# ------ Time: 17.5---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.478571 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.5 us/neur )
# ------ Time: 17.6---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.475714 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.708571 us/neur )
# ------ Time: 17.7---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.667143 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.505714 us/neur )
# ------ Time: 17.8---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.485714 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.484286 us/neur )
# ------ Time: 17.9---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.471429 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.475714 us/neur )
# ------ Time: 18---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.505714 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.477143 us/neur )
# ------ Time: 18.1---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.471429 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.475714 us/neur )
# ------ Time: 18.2---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.47 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.475714 us/neur )
# ------ Time: 18.3---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.471429 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.478571 us/neur )
# ------ Time: 18.4---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.477143 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.468571 us/neur )
# ------ Time: 18.5---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.507143 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.524286 us/neur )
# ------ Time: 18.6---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.524286 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.492857 us/neur )
# ------ Time: 18.7---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.478571 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.47 us/neur )
# ------ Time: 18.8---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.502857 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.477143 us/neur )
# ------ Time: 18.9---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.47 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.472857 us/neur )
# ------ Time: 19---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.501429 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.478571 us/neur )
# ------ Time: 19.1---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.475714 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.468571 us/neur )
# ------ Time: 19.2---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.477143 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.475714 us/neur )
# ------ Time: 19.3---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.474286 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.474286 us/neur )
# ------ Time: 19.4---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.474286 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.474286 us/neur )
# ------ Time: 19.5---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.488571 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.492857 us/neur )
# ------ Time: 19.6---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.475714 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.471429 us/neur )
# ------ Time: 19.7---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.474286 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.605714 us/neur )
# ------ Time: 19.8---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.595714 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.53 us/neur )
# ------ Time: 19.9---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.525714 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.537143 us/neur )
# ------ Time: 20---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.501429 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.481429 us/neur )
# ------ Time: 20.1---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.474286 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.477143 us/neur )
# ------ Time: 20.2---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.478571 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.474286 us/neur )
# ------ Time: 20.3---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.475714 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.478571 us/neur )
# ------ Time: 20.4---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.48 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.475714 us/neur )
# ------ Time: 20.5---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.522857 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.488571 us/neur )
# ------ Time: 20.6---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.474286 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.475714 us/neur )
# ------ Time: 20.7---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.47 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.48 us/neur )
# ------ Time: 20.8---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.474286 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.477143 us/neur )
# ------ Time: 20.9---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.491429 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.474286 us/neur )
# ------ Time: 21---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.508571 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.474286 us/neur )
# ------ Time: 21.1---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.475714 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.472857 us/neur )
# ------ Time: 21.2---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.475714 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.474286 us/neur )
# ------ Time: 21.3---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.474286 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.47 us/neur )
# ------ Time: 21.4---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.468571 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.477143 us/neur )
# ------ Time: 21.5---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.492857 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.48 us/neur )
# ------ Time: 21.6---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.474286 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.471429 us/neur )
# ------ Time: 21.7---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.475714 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.471429 us/neur )
# ------ Time: 21.8---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.475714 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.655714 us/neur )
# ------ Time: 21.9---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.618571 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.537143 us/neur )
# ------ Time: 22---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.517143 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.48 us/neur )
# ------ Time: 22.1---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.475714 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.475714 us/neur )
# ------ Time: 22.2---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.472857 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.47 us/neur )
# ------ Time: 22.3---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.478571 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.478571 us/neur )
# ------ Time: 22.4---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.472857 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.468571 us/neur )
# ------ Time: 22.5---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.505714 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.475714 us/neur )
# ------ Time: 22.6---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.471429 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.477143 us/neur )
# ------ Time: 22.7---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.472857 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.48 us/neur )
# ------ Time: 22.8---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.48 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.471429 us/neur )
# ------ Time: 22.9---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.475714 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.475714 us/neur )
# ------ Time: 23---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.49 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.502857 us/neur )
# ------ Time: 23.1---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.475714 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.471429 us/neur )
# ------ Time: 23.2---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.472857 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.47 us/neur )
# ------ Time: 23.3---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.475714 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.474286 us/neur )
# ------ Time: 23.4---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.472857 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.475714 us/neur )
# ------ Time: 23.5---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.488571 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.492857 us/neur )
# ------ Time: 23.6---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.477143 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.471429 us/neur )
# ------ Time: 23.7---------
# pop 0) average synaptic queue is long 139.934
# pop 0) evolving took 0 ms (0.475714 us/neur )
# pop 1) average synaptic queue is long 140.951
# pop 1) evolving took 0 ms (0.478571 us/neur )
# ------ Time: 23.8---------
# ...
# pop 0) evolving took 0 ms (0.581429 us/neur )
# pop 1) average synaptic queue is long 22.3743
# pop 1) evolving took 0 ms (0.594286 us/neur )
# ------ Time: 192.6---------
# pop 0) average synaptic queue is long 21.5129
# pop 0) evolving took 0 ms (0.72 us/neur )
# pop 1) average synaptic queue is long 22.0371
# pop 1) evolving took 0 ms (0.605714 us/neur )
# ------ Time: 192.7---------
# pop 0) average synaptic queue is long 21.2286
# pop 0) evolving took 0 ms (0.578571 us/neur )
# pop 1) average synaptic queue is long 21.7514
# pop 1) evolving took 0 ms (0.584286 us/neur )
# ------ Time: 192.8---------
# pop 0) average synaptic queue is long 21.18
# pop 0) evolving took 0 ms (0.577143 us/neur )
# pop 1) average synaptic queue is long 21.5943
# pop 1) evolving took 0 ms (0.585714 us/neur )
# ------ Time: 192.9---------
# pop 0) average synaptic queue is long 21.08
# pop 0) evolving took 0 ms (0.561429 us/neur )
# pop 1) average synaptic queue is long 21.24
# pop 1) evolving took 0 ms (0.578571 us/neur )
# ------ Time: 193---------
# pop 0) average synaptic queue is long 21.1471
# pop 0) evolving took 0 ms (0.557143 us/neur )
# pop 1) average synaptic queue is long 20.9386
# pop 1) evolving took 0 ms (0.567143 us/neur )
# ------ Time: 193.1---------
# pop 0) average synaptic queue is long 21.0257
# pop 0) evolving took 0 ms (0.568571 us/neur )
# pop 1) average synaptic queue is long 21.0129
# pop 1) evolving took 0 ms (0.564286 us/neur )
# ------ Time: 193.2---------
# pop 0) average synaptic queue is long 20.8343
# pop 0) evolving took 0 ms (0.505714 us/neur )
# pop 1) average synaptic queue is long 20.6057
# pop 1) evolving took 0 ms (0.511429 us/neur )
# ------ Time: 193.3---------
# pop 0) average synaptic queue is long 20.75
# pop 0) evolving took 0 ms (0.557143 us/neur )
# pop 1) average synaptic queue is long 20.4843
# pop 1) evolving took 0 ms (0.52 us/neur )
# ------ Time: 193.4---------
# pop 0) average synaptic queue is long 20.5114
# pop 0) evolving took 0 ms (0.51 us/neur )
# pop 1) average synaptic queue is long 20.31
# pop 1) evolving took 0 ms (0.505714 us/neur )
# ------ Time: 193.5---------
# pop 0) average synaptic queue is long 20.45
# pop 0) evolving took 0 ms (0.522857 us/neur )
# pop 1) average synaptic queue is long 20.4314
# pop 1) evolving took 0 ms (0.512857 us/neur )
# ------ Time: 193.6---------
# pop 0) average synaptic queue is long 20.4229
# pop 0) evolving took 0 ms (0.505714 us/neur )
# pop 1) average synaptic queue is long 20.1171
# pop 1) evolving took 0 ms (0.508571 us/neur )
# ------ Time: 193.7---------
# pop 0) average synaptic queue is long 20.0814
# pop 0) evolving took 0 ms (0.565714 us/neur )
# pop 1) average synaptic queue is long 19.9629
# pop 1) evolving took 0 ms (0.555714 us/neur )
# ------ Time: 193.8---------
# pop 0) average synaptic queue is long 19.8243
# pop 0) evolving took 0 ms (0.522857 us/neur )
# pop 1) average synaptic queue is long 19.6586
# pop 1) evolving took 0 ms (0.52 us/neur )
# ------ Time: 193.9---------
# pop 0) average synaptic queue is long 20.1071
# pop 0) evolving took 0 ms (0.508571 us/neur )
# pop 1) average synaptic queue is long 19.71
# pop 1) evolving took 0 ms (0.527143 us/neur )
# ------ Time: 194---------
# pop 0) average synaptic queue is long 19.8814
# pop 0) evolving took 0 ms (0.56 us/neur )
# pop 1) average synaptic queue is long 19.3957
# pop 1) evolving took 0 ms (0.554286 us/neur )
# ------ Time: 194.1---------
# pop 0) average synaptic queue is long 19.7729
# pop 0) evolving took 0 ms (0.752857 us/neur )
# pop 1) average synaptic queue is long 19.1571
# pop 1) evolving took 0 ms (0.578571 us/neur )
# ------ Time: 194.2---------
# pop 0) average synaptic queue is long 19.5229
# pop 0) evolving took 0 ms (0.591429 us/neur )
# pop 1) average synaptic queue is long 19.0143
# pop 1) evolving took 0 ms (0.575714 us/neur )
# ------ Time: 194.3---------
# pop 0) average synaptic queue is long 19.9186
# pop 0) evolving took 0 ms (0.585714 us/neur )
# pop 1) average synaptic queue is long 19.4486
# pop 1) evolving took 0 ms (0.558571 us/neur )
# ------ Time: 194.4---------
# pop 0) average synaptic queue is long 20.0129
# pop 0) evolving took 0 ms (0.58 us/neur )
# pop 1) average synaptic queue is long 19.1814
# pop 1) evolving took 0 ms (0.611429 us/neur )
# ------ Time: 194.5---------
# pop 0) average synaptic queue is long 20.2871
# pop 0) evolving took 0 ms (0.622857 us/neur )
# pop 1) average synaptic queue is long 19.6629
# pop 1) evolving took 0 ms (0.591429 us/neur )
# ------ Time: 194.6---------
# pop 0) average synaptic queue is long 20.7814
# pop 0) evolving took 0 ms (0.601429 us/neur )
# pop 1) average synaptic queue is long 19.8714
# pop 1) evolving took 0 ms (0.532857 us/neur )
# ------ Time: 194.7---------
# pop 0) average synaptic queue is long 20.5543
# pop 0) evolving took 0 ms (0.522857 us/neur )
# pop 1) average synaptic queue is long 19.9157
# pop 1) evolving took 0 ms (0.51 us/neur )
# ------ Time: 194.8---------
# pop 0) average synaptic queue is long 20.5286
# pop 0) evolving took 0 ms (0.518571 us/neur )
# pop 1) average synaptic queue is long 19.6429
# pop 1) evolving took 0 ms (0.502857 us/neur )
# ------ Time: 194.9---------
# pop 0) average synaptic queue is long 20.2329
# pop 0) evolving took 0 ms (0.52 us/neur )
# pop 1) average synaptic queue is long 19.7514
# pop 1) evolving took 0 ms (0.517143 us/neur )
# ------ Time: 195---------
# pop 0) average synaptic queue is long 20.41
# pop 0) evolving took 0 ms (0.512857 us/neur )
# pop 1) average synaptic queue is long 19.7829
# pop 1) evolving took 0 ms (0.508571 us/neur )
# ------ Time: 195.1---------
# pop 0) average synaptic queue is long 20.5343
# pop 0) evolving took 0 ms (0.561429 us/neur )
# pop 1) average synaptic queue is long 19.7671
# pop 1) evolving took 0 ms (0.56 us/neur )
# ------ Time: 195.2---------
# pop 0) average synaptic queue is long 20.5229
# pop 0) evolving took 0 ms (0.572857 us/neur )
# pop 1) average synaptic queue is long 19.93
# pop 1) evolving took 0 ms (0.498571 us/neur )
# ------ Time: 195.3---------
# pop 0) average synaptic queue is long 20.33
# pop 0) evolving took 0 ms (0.512857 us/neur )
# pop 1) average synaptic queue is long 20.0529
# pop 1) evolving took 0 ms (0.508571 us/neur )
# ------ Time: 195.4---------
# pop 0) average synaptic queue is long 20.5414
# pop 0) evolving took 0 ms (0.514286 us/neur )
# pop 1) average synaptic queue is long 20.2814
# pop 1) evolving took 0 ms (0.508571 us/neur )
# ------ Time: 195.5---------
# pop 0) average synaptic queue is long 20.7386
# pop 0) evolving took 0 ms (0.531429 us/neur )
# pop 1) average synaptic queue is long 20.5086
# pop 1) evolving took 0 ms (0.571429 us/neur )
# ------ Time: 195.6---------
# pop 0) average synaptic queue is long 20.9257
# pop 0) evolving took 0 ms (0.554286 us/neur )
# pop 1) average synaptic queue is long 20.5414
# pop 1) evolving took 0 ms (0.592857 us/neur )
# ------ Time: 195.7---------
# pop 0) average synaptic queue is long 21.01
# pop 0) evolving took 0 ms (0.571429 us/neur )
# pop 1) average synaptic queue is long 21.0214
# pop 1) evolving took 0 ms (0.51 us/neur )
# ------ Time: 195.8---------
# pop 0) average synaptic queue is long 21.2
# pop 0) evolving took 0 ms (0.528571 us/neur )
# pop 1) average synaptic queue is long 20.8629
# pop 1) evolving took 0 ms (0.554286 us/neur )
# ------ Time: 195.9---------
# pop 0) average synaptic queue is long 21.0629
# pop 0) evolving took 0 ms (0.575714 us/neur )
# pop 1) average synaptic queue is long 21.3686
# pop 1) evolving took 0 ms (0.684286 us/neur )
# ------ Time: 196---------
# pop 0) average synaptic queue is long 21.37
# pop 0) evolving took 0 ms (0.627143 us/neur )
# pop 1) average synaptic queue is long 21.76
# pop 1) evolving took 0 ms (0.662857 us/neur )
# ------ Time: 196.1---------
# pop 0) average synaptic queue is long 21.2371
# pop 0) evolving took 0 ms (0.561429 us/neur )
# pop 1) average synaptic queue is long 21.4571
# pop 1) evolving took 0 ms (0.588571 us/neur )
# ------ Time: 196.2---------
# pop 0) average synaptic queue is long 21.5229
# pop 0) evolving took 0 ms (0.568571 us/neur )
# pop 1) average synaptic queue is long 21.51
# pop 1) evolving took 0 ms (0.575714 us/neur )
# ------ Time: 196.3---------
# pop 0) average synaptic queue is long 21.49
# pop 0) evolving took 0 ms (0.598571 us/neur )
# pop 1) average synaptic queue is long 22.2886
# pop 1) evolving took 0 ms (0.675714 us/neur )
# ------ Time: 196.4---------
# pop 0) average synaptic queue is long 21.8
# pop 0) evolving took 0 ms (0.588571 us/neur )
# pop 1) average synaptic queue is long 22.5229
# pop 1) evolving took 0 ms (0.525714 us/neur )
# ------ Time: 196.5---------
# pop 0) average synaptic queue is long 21.8414
# pop 0) evolving took 0 ms (0.532857 us/neur )
# pop 1) average synaptic queue is long 22.9243
# pop 1) evolving took 0 ms (0.532857 us/neur )
# ------ Time: 196.6---------
# pop 0) average synaptic queue is long 22.0943
# pop 0) evolving took 0 ms (0.524286 us/neur )
# pop 1) average synaptic queue is long 23.0886
# pop 1) evolving took 0 ms (0.524286 us/neur )
# ------ Time: 196.7---------
# pop 0) average synaptic queue is long 22.2586
# pop 0) evolving took 0 ms (0.561429 us/neur )
# pop 1) average synaptic queue is long 24.1257
# pop 1) evolving took 0 ms (0.531429 us/neur )
# ------ Time: 196.8---------
# pop 0) average synaptic queue is long 22.8243
# pop 0) evolving took 0 ms (0.524286 us/neur )
# pop 1) average synaptic queue is long 24.3514
# pop 1) evolving took 0 ms (0.621429 us/neur )
# ------ Time: 196.9---------
# pop 0) average synaptic queue is long 22.9629
# pop 0) evolving took 0 ms (0.531429 us/neur )
# pop 1) average synaptic queue is long 24.7586
# pop 1) evolving took 0 ms (0.531429 us/neur )
# ------ Time: 197---------
# pop 0) average synaptic queue is long 23.2086
# pop 0) evolving took 0 ms (0.531429 us/neur )
# pop 1) average synaptic queue is long 25.1514
# pop 1) evolving took 0 ms (0.511429 us/neur )
# ------ Time: 197.1---------
# pop 0) average synaptic queue is long 23.2314
# pop 0) evolving took 0 ms (0.53 us/neur )
# pop 1) average synaptic queue is long 25.7143
# pop 1) evolving took 0 ms (0.535714 us/neur )
# ------ Time: 197.2---------
# pop 0) average synaptic queue is long 24.2443
# pop 0) evolving took 0 ms (0.51 us/neur )
# pop 1) average synaptic queue is long 25.9557
# pop 1) evolving took 0 ms (0.538571 us/neur )
# ------ Time: 197.3---------
# pop 0) average synaptic queue is long 25.2257
# pop 0) evolving took 0 ms (0.561429 us/neur )
# pop 1) average synaptic queue is long 25.9529
# pop 1) evolving took 0 ms (0.525714 us/neur )
# ------ Time: 197.4---------
# pop 0) average synaptic queue is long 25.5414
# pop 0) evolving took 0 ms (0.672857 us/neur )
# pop 1) average synaptic queue is long 26.5257
# pop 1) evolving took 0 ms (0.581429 us/neur )
# ------ Time: 197.5---------
# pop 0) average synaptic queue is long 26.06
# pop 0) evolving took 0 ms (0.572857 us/neur )
# pop 1) average synaptic queue is long 26.46
# pop 1) evolving took 0 ms (0.581429 us/neur )
# ------ Time: 197.6---------
# pop 0) average synaptic queue is long 26.4329
# pop 0) evolving took 0 ms (0.587143 us/neur )
# pop 1) average synaptic queue is long 27.2329
# pop 1) evolving took 0 ms (0.587143 us/neur )
# ------ Time: 197.7---------
# pop 0) average synaptic queue is long 27.4443
# pop 0) evolving took 0 ms (0.958571 us/neur )
# pop 1) average synaptic queue is long 28.3043
# pop 1) evolving took 0 ms (0.602857 us/neur )
# ------ Time: 197.8---------
# pop 0) average synaptic queue is long 27.8657
# pop 0) evolving took 0 ms (0.844286 us/neur )
# pop 1) average synaptic queue is long 28.38
# pop 1) evolving took 0 ms (0.7 us/neur )
# ------ Time: 197.9---------
# pop 0) average synaptic queue is long 28.4014
# pop 0) evolving took 0 ms (0.618571 us/neur )
# pop 1) average synaptic queue is long 28.8043
# pop 1) evolving took 0 ms (0.648571 us/neur )
# ------ Time: 198---------
# pop 0) average synaptic queue is long 29.8029
# pop 0) evolving took 0 ms (0.764286 us/neur )
# pop 1) average synaptic queue is long 29.5643
# pop 1) evolving took 0 ms (0.645714 us/neur )
# ------ Time: 198.1---------
# pop 0) average synaptic queue is long 30.2514
# pop 0) evolving took 0 ms (0.711429 us/neur )
# pop 1) average synaptic queue is long 29.4771
# pop 1) evolving took 0 ms (0.568571 us/neur )
# ------ Time: 198.2---------
# pop 0) average synaptic queue is long 30.1814
# pop 0) evolving took 0 ms (0.552857 us/neur )
# pop 1) average synaptic queue is long 30.1143
# pop 1) evolving took 0 ms (0.544286 us/neur )
# ------ Time: 198.3---------
# pop 0) average synaptic queue is long 30.8186
# pop 0) evolving took 0 ms (0.538571 us/neur )
# pop 1) average synaptic queue is long 30.5
# pop 1) evolving took 0 ms (0.525714 us/neur )
# ------ Time: 198.4---------
# pop 0) average synaptic queue is long 31.0229
# pop 0) evolving took 0 ms (0.531429 us/neur )
# pop 1) average synaptic queue is long 30.9843
# pop 1) evolving took 0 ms (0.554286 us/neur )
# ------ Time: 198.5---------
# pop 0) average synaptic queue is long 31.72
# pop 0) evolving took 0 ms (0.602857 us/neur )
# pop 1) average synaptic queue is long 31.8043
# pop 1) evolving took 0 ms (0.555714 us/neur )
# ------ Time: 198.6---------
# pop 0) average synaptic queue is long 33.4286
# pop 0) evolving took 0 ms (0.548571 us/neur )
# pop 1) average synaptic queue is long 33.14
# pop 1) evolving took 0 ms (0.531429 us/neur )
# ------ Time: 198.7---------
# pop 0) average synaptic queue is long 34
# pop 0) evolving took 0 ms (0.541429 us/neur )
# pop 1) average synaptic queue is long 34.2843
# pop 1) evolving took 0 ms (0.535714 us/neur )
# ------ Time: 198.8---------
# pop 0) average synaptic queue is long 34.4129
# pop 0) evolving took 0 ms (0.548571 us/neur )
# pop 1) average synaptic queue is long 35.17
# pop 1) evolving took 0 ms (0.521429 us/neur )
# ------ Time: 198.9---------
# pop 0) average synaptic queue is long 34.6643
# pop 0) evolving took 0 ms (0.56 us/neur )
# pop 1) average synaptic queue is long 36.4571
# pop 1) evolving took 0 ms (0.61 us/neur )
# ------ Time: 199---------
# pop 0) average synaptic queue is long 36.2843
# pop 0) evolving took 0 ms (0.624286 us/neur )
# pop 1) average synaptic queue is long 37.8971
# pop 1) evolving took 0 ms (0.625714 us/neur )
# ------ Time: 199.1---------
# pop 0) average synaptic queue is long 37.5157
# pop 0) evolving took 0 ms (0.648571 us/neur )
# pop 1) average synaptic queue is long 39.5529
# pop 1) evolving took 0 ms (0.572857 us/neur )
# ------ Time: 199.2---------
# pop 0) average synaptic queue is long 37.78
# pop 0) evolving took 0 ms (0.584286 us/neur )
# pop 1) average synaptic queue is long 40.1514
# pop 1) evolving took 0 ms (0.571429 us/neur )
# ------ Time: 199.3---------
# pop 0) average synaptic queue is long 39.9371
# pop 0) evolving took 0 ms (0.592857 us/neur )
# pop 1) average synaptic queue is long 41.6314
# pop 1) evolving took 0 ms (0.584286 us/neur )
# ------ Time: 199.4---------
# pop 0) average synaptic queue is long 40.8114
# pop 0) evolving took 0 ms (0.577143 us/neur )
# pop 1) average synaptic queue is long 43.5914
# pop 1) evolving took 0 ms (0.992857 us/neur )
# ------ Time: 199.5---------
# pop 0) average synaptic queue is long 42.1886
# pop 0) evolving took 0 ms (0.668571 us/neur )
# pop 1) average synaptic queue is long 43.84
# pop 1) evolving took 0 ms (0.834286 us/neur )
# ------ Time: 199.6---------
# pop 0) average synaptic queue is long 43.37
# pop 0) evolving took 0 ms (0.655714 us/neur )
# pop 1) average synaptic queue is long 44.94
# pop 1) evolving took 0 ms (0.675714 us/neur )
# ------ Time: 199.7---------
# pop 0) average synaptic queue is long 44.7671
# pop 0) evolving took 0 ms (0.728571 us/neur )
# pop 1) average synaptic queue is long 46.2414
# pop 1) evolving took 0 ms (0.787143 us/neur )
# ------ Time: 199.8---------
# pop 0) average synaptic queue is long 46.7943
# pop 0) evolving took 0 ms (0.785714 us/neur )
# pop 1) average synaptic queue is long 47.2043
# pop 1) evolving took 0 ms (0.594286 us/neur )
# ------ Time: 199.9---------
# pop 0) average synaptic queue is long 47.1957
# pop 0) evolving took 0 ms (0.598571 us/neur )
# pop 1) average synaptic queue is long 48.5914
# pop 1) evolving took 0 ms (0.611429 us/neur )
# ------ Time: 200---------
# pop 0) average synaptic queue is long 48.86
# pop 0) evolving took 0 ms (0.628571 us/neur )
# pop 1) average synaptic queue is long 49.8657
# pop 1) evolving took 0 ms (0.652857 us/neur )
# simulation took 1 s	(0.00049975 s/step)
# 	Gathering time avg: 118.928 us/step
# 	Inject time avg: 0 us/step

# %%
albert_spikes = spikenet.populations['Albert'].get_data()["spikes"]
monalisa_spikes = spikenet.populations['MonaLisa'].get_data()["spikes"]

plt.step(np.arange(len(albert_spikes)), albert_spikes, alpha=0.3)
plt.step(np.arange(len(albert_spikes)), monalisa_spikes, alpha=0.3)
N = 10
plt.plot(np.convolve(albert_spikes, np.ones(N)/N))
states = np.array(spikenet.populations['Albert'].get_data()['states'])
print(states.shape)
# Out:
# (2001, 700, 4)

# %%
for i in range(1):
    plt.plot(states[:, i, 0],marker=".")
    print(states[:, i, 0])
    plt.title("V")
# Out:
# [-69.37112908 -69.12150592 -68.87200755 ... -32.56867499 -32.40634858
#  -32.23544094]

# %%
for i in range(5):
    plt.plot(states[:, i, 1],marker=".")
    plt.title("gsyn_exc")

# %%
for i in range(5):
    plt.plot(states[:, i, 2],marker=".")
    plt.title("gsyn_inh")

# %%
for i in range(5):
    plt.plot(states[:, i, 3],marker=".")
    plt.title("u")

# %%
states = np.array(spikenet.populations['MonaLisa'].get_data()['states'])

for idx, feat in enumerate(["V", "gsyne", "gsyni", "u"]):
    plt.plot(states[:, 0, idx], label=feat)
plt.title("MonaLisa")
plt.legend()


plt.show()
